# %%
from pyspark import SparkConf, SparkContext
sc = SparkContext(conf=SparkConf().setAppName("MyApp").setMaster("local"))

import re

def parse_article(line):
    try:
        article_id, text = unicode(line.rstrip()).split('\t', 1)
        text = re.sub("^\W+|\W+$", "", text, flags=re.UNICODE)
        words = re.split("\W*\s+\W*", text, flags=re.UNICODE)
        return words
    except ValueError as e:
        return []

wiki = sc.textFile("/data/wiki/en_articles_part/articles-part", 16).map(parse_article)

# %% [markdown]
# Footnote: `sc.textFile(String path, int minPartitions)`

# %%
result = wiki.take(1)[0]
print(result)
# Out:
# [u'Anarchism', u'Anarchism', u'is', u'often', u'defined', u'as', u'a', u'political', u'philosophy', u'which', u'holds', u'the', u'state', u'to', u'be', u'undesirable', u'unnecessary', u'or', u'harmful', u'The', u'following', u'sources', u'cite', u'anarchism', u'as', u'a', u'political', u'philosophy', u'Slevin', u'Carl', u'Anarchism', u'The', u'Concise', u'Oxford', u'Dictionary', u'of', u'Politics', u'Ed', u'Iain', u'McLean', u'and', u'Alistair', u'McMillan', u'Oxford', u'University', u'Press', u'2003', u'However', u'others', u'argue', u'that', u'while', u'anti-statism', u'is', u'central', u'it', u'is', u'inadequate', u'to', u'define', u'anarchism', u'Therefore', u'they', u'argue', u'instead', u'that', u'anarchism', u'entails', u'opposing', u'authority', u'or', u'hierarchical', u'organization', u'in', u'the', u'conduct', u'of', u'human', u'relations', u'including', u'but', u'not', u'only', u'the', u'state', u'system', u'Proponents', u'of', u'anarchism', u'known', u'as', u'anarchists', u'advocate', u'stateless', u'societies', u'based', u'on', u'non-hierarchical', u'free', u'associations', u'As', u'a', u'subtle', u'and', u'anti-dogmatic', u'philosophy', u'anarchism', u'draws', u'on', u'many', u'currents', u'of', u'thought', u'and', u'strategy', u'Anarchism', u'does', u'not', u'offer', u'a', u'fixed', u'body', u'of', u'doctrine', u'from', u'a', u'single', u'particular', u'world', u'view', u'instead', u'fluxing', u'and', u'flowing', u'as', u'a', u'philosophy', u'There', u'are', u'many', u'types', u'and', u'traditions', u'of', u'anarchism', u'not', u'all', u'of', u'which', u'are', u'mutually', u'exclusive', u'Anarchist', u'schools', u'of', u'thought', u'can', u'differ', u'fundamentally', u'supporting', u'anything', u'from', u'extreme', u'individualism', u'to', u'complete', u'collectivism', u'Strains', u'of', u'anarchism', u'have', u'often', u'been', u'divided', u'into', u'the', u'categories', u'of', u'social', u'and', u'individualist', u'anarchism', u'or', u'similar', u'dual', u'classifications', u'Ostergaard', u'Geoffrey', u'Anarchism', u'The', u'Blackwell', u'Dictionary', u'of', u'Modern', u'Social', u'Thought', u'Blackwell', u'Publishing', u'p', u'14', u'Anarchism', u'is', u'often', u'considered', u'a', u'radical', u'left-wing', u'ideology', u'and', u'much', u'of', u'anarchist', u'economics', u'and', u'anarchist', u'legal', u'philosophy', u'reflect', u'anti-authoritarian', u'interpretations', u'of', u'communism', u'collectivism', u'syndicalism', u'mutualism', u'or', u'participatory', u'economics', u'Anarchism', u'as', u'a', u'mass', u'social', u'movement', u'has', u'regularly', u'endured', u'fluctuations', u'in', u'popularity', u'The', u'central', u'tendency', u'of', u'anarchism', u'as', u'a', u'social', u'movement', u'has', u'been', u'represented', u'by', u'anarcho-communism', u'and', u'anarcho-syndicalism', u'with', u'individualist', u'anarchism', u'being', u'primarily', u'a', u'literary', u'phenomenon', u'which', u'nevertheless', u'did', u'have', u'an', u'impact', u'on', u'the', u'bigger', u'currents', u'and', u'individualists', u'have', u'also', u'participated', u'in', u'large', u'anarchist', u'organizations', u'Many', u'anarchists', u'oppose', u'all', u'forms', u'of', u'aggression', u'supporting', u'self-defense', u'or', u'non-violence', u'anarcho-pacifism', u'George', u'Woodcock', u'Anarchism', u'A', u'History', u'of', u'Libertarian', u'Ideas', u'and', u'Movements', u'1962', u'while', u'others', u'have', u'supported', u'the', u'use', u'of', u'some', u'coercive', u'measures', u'including', u'violent', u'revolution', u'and', u'propaganda', u'of', u'the', u'deed', u'on', u'the', u'path', u'to', u'an', u'anarchist', u'society', u'Etymology', u'and', u'terminology', u'The', u'term', u'derives', u'from', u'the', u'ancient', u'Greek', u'\u1f04\u03bd\u03b1\u03c1\u03c7\u03bf\u03c2', u'anarchos', u'meaning', u'without', u'rulers', u'from', u'the', u'prefix', u'\u1f00\u03bd', u'an', u'without', u'\u1f00\u03c1\u03c7\u03cc\u03c2', u'ark ...

# %% [markdown]
# Footnote:
# 1. the return array is a list of lists.
# 2. when use `take(2)`, the return array will be a list of 2 lists.

# %%
# convert every word to lower case
wiki = wiki.map(lambda words: [word.lower() for word in words])

# %%
def parse_word_pair_with_start_word(words, start_word='word'):
    pairs = []
    for i, word in enumerate(words[:-1]):
        if word == start_word:
            word_pair = '{}_{}'.format(word,words[i+1])
            pairs.append((word_pair, 1))
        else:
            continue
    return pairs

# %%
# pick up every word pair with starting word of 'narodnaya'
# the flatMap will combine all word pair together
wiki_word_pair = wiki.flatMap(lambda words: parse_word_pair_with_start_word(words, start_word='narodnaya'))

# %%
# have a look at the result dataset
wiki_word_pair.take(3)
# Out:
# [('narodnaya_volya', 1), ('narodnaya_volya', 1), ('narodnaya_volya', 1)]

# %%
# create a key RDD and aggregate all count
wiki_word_pair_agg = wiki_word_pair.reduceByKey(lambda a, b: a+b)

# sort by key
wiki_word_pair_agg_sort = wiki_word_pair_agg.sortByKey()

# %%
final_result = wiki_word_pair_agg_sort.collect()
for word_pair, count in final_result:
    print '{}\t{}'.format(word_pair, count)
# Out:
# narodnaya_gazeta	1
# narodnaya_volya	9
